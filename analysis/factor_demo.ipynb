# %% [markdown]
# # factor_demo

# %% [markdown]
# ## 导入模块

# %%
import sys
sys.path.append('../../public-Git/')

from demo_Alpha.factor_function import *
from utils.stg_functions_local import *
from utils.performance import corr_local_V2

# %matplotlib inline

# %% [markdown]
# ## 定义股票池和基准指数

# %%
stock_universe = '999998'
index_code = '000905'

# %% [markdown]
# ## 定义因子类

# %%
class ret_jump(Factor):
    name = 'fill_ret_jump'
    islimitbuy = False
    islimitsell = False
    dependencies = ['close']

    def calc(self, data):
        close = data['close']
        factor = feather.read_dataframe('../data/ret_jump/fill_neutral_ret_jump.feather')
        factor = factor.pivot(index='date', columns='issue', values='ret_jump')
        factor = factor.reindex(index=close.index, columns=close.columns)
        return factor

# %%
class N_connect(Factor):
    name = 'fill_N_connect'
    islimitbuy = False
    islimitsell = False
    dependencies = ['close']

    def calc(self, data):
        close = data['close']
        factor = feather.read_dataframe('../data/N_connect_1_any/fill_neutral_N_connect_num.feather')
        factor = factor.pivot(index='date', columns='issue', values='neutral_factor')
        factor = factor.reindex(index=close.index, columns=close.columns)
        return factor

# %%
class peer_relative_ret(Factor):
    name = 'fill_peer_relative_ret'
    islimitbuy = False
    islimitsell = False
    dependencies = ['close']

    def calc(self, data):
        close = data['close']
        factor = feather.read_dataframe('../data/peer_ret/fill_neutral_peer_ret_num.feather')
        factor = factor.pivot(index='date', columns='issue', values='peer_relative_ret')
        factor = factor.reindex(index=close.index, columns=close.columns)
        return factor

# %% [markdown]
# ## 回测

# %%
# start_datetime = datetime.datetime(2019, 1, 1)
# end_datetime = datetime.datetime(2024, 5, 31)

start_datetime = datetime.datetime(2019, 8, 1)
end_datetime = datetime.datetime(2024, 12, 31)

factor = peer_relative_ret()

time_tik = datetime.datetime.now()
print(f"开始计算{factor.name}")
factorResults = analysis(
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    factor_objs=[factor,],
    stock_universe=stock_universe,
    benchmark=index_code,
    plot=True
)
print(f"{factor.name}计算完成，耗时{datetime.datetime.now()-time_tik}")

# %
date_index = pd.to_datetime(
    sd.get_trade_date(
        start_datetime.strftime('%Y-%m-%d'),
        end_datetime.strftime('%Y-%m-%d')
    )['trade_date']
)
dailyExcessReturns = (
    factorResults['ret_Data']['ret_wide_ae']
        .iloc[:, -1]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyIC = (
    factorResults['IC_data_raw']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyICLong = (
    factorResults['ic_data_long']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyICShort = (
    factorResults['ic_data_short']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)

print('2023年以前')
RetCorr_Table, RetR2_Table, ICCorr_Table, ICLCorr_Table, ICSCorr_Table = corr_local_V2(
    dailyExcessReturns,
    dailyIC,
    dailyICLong,
    dailyICShort,
    lastday=datetime.datetime(2023, 12, 31),
    warnings=0.6
)
print('*'*10)
print('全样本除2024年1、2月')
RetCorr_Table, RetR2_Table, ICCorr_Table, ICLCorr_Table, ICSCorr_Table = corr_local_V2(
    dailyExcessReturns,
    dailyIC,
    dailyICLong,
    dailyICShort,
    lastday=datetime.datetime(2025, 12, 31),
    warnings=0.6
)
# Out:
# 开始计算fill_peer_relative_ret
# 因子数据计算完成，耗时0:00:01.561936
# ********************************************************************************************************************************************************************************************************
#
# ********************************************************************************************************************************************************************************************************
# fill_peer_relative_ret------输出对标超额收益模式指标
# Dropped 0.1% entries from factor data: 0.1% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 5.0%, not exceeded: OK!
# FactorValues Quantiles Statistics
#                       min       max      mean       std   count  daily_count  \
# factor_quantile
# 1               -0.084673 -0.003873 -0.013231  0.006151  128492         99.0
# 2               -0.028188 -0.003280 -0.009438  0.003680  127907         98.0
# 3               -0.023838 -0.002887 -0.008005  0.003135  127842         98.0
# 4               -0.020912 -0.002593 -0.007041  0.002774  127892         98.0
# 5               -0.018828 -0.002350 -0.006290  0.002488  127695         98.0
# 6               -0.016927 -0.002122 -0.005663  0.002243  127894         98.0
# 7               -0.015630 -0.001915 -0.005113  0.002037  128002         99.0
# 8               -0.014122 -0.001776 -0.004622  0.001838  127836         98.0
# 9               -0.012581 -0.001612 -0.004184  0.001664  127827         98.0
# 10              -0.011350 -0.001483 -0.003779  0.001497  127775         98.0
# 11              -0.010257 -0.001353 -0.003409  0.001359  127869         98.0
# 12              -0.009231 -0.001217 -0.003056  0.001226  127867         98.0
# 13              -0.008380 -0.001038 -0.002722  0.001110  127933         99.0
# 14              -0.007479 -0.000923 -0.002397  0.000978  127906         98.0
# 15              -0.006506 -0.000824 -0.002089  0.000856  127736         98.0
# 16              -0.005612 -0.000649 -0.001789  0.000746  127887         98.0
# 17              -0.004859 -0.000491 -0.001498  0.000648  127874         98.0
# 18              -0.004087 -0.000334 -0.001217  0.000554  127783         98.0
# 19              -0.003322 -0.000168 -0.000936  0.000462  128042         99.0
# 20              -0.002485 -0.000030 -0.000654  0.000379  127754         98.0
# 21              -0.001687  0.000283 -0.000374  0.000317  127871         98.0
# 22              -0.001163  0.000880 -0.000095  0.000290  127784         98.0
# 23              -0.000824  0.001431  0.000182  0.000301  127879         98.0
# 24              -0.000515  0.001998  0.000462  0.000355  127764         98.0
# 25              -0.000148  0.002457  0.000742  0.000426  128025         99.0
# 26               0.000156  0.003000  0.001024  0.000515  127800         98.0
# 27               0.000276  0.003823  0.001312  0.000605  127874         98.0
# 28               0.000436  0.004673  0.001603  0.000704  127871         98.0
# 29               0.000577  0.005767  0.001907  0.000826  127752         98.0
# 30               0.000701  0.006655  0.002221  0.000946  127891         98.0
# 31               0.000839  0.007612  0.002545  0.001074  127946         99.0
# 32               0.000974  0.008711  0.002886  0.001205  127869         98.0
# 33               0.001135  0.009788  0.003247  0.001351  127869         98.0
# 34               0.001285  0.010836  0.003627  0.001499  127766         98.0
# 35               0.001417  0.011807  0.004034  0.001641  127836         98.0
# 36               0.001561  0.013130  0.004474  0.001804  127823         98.0
# 37               0.001748  0.014738  0.004966  0.002003  128015         99.0
# 38               0.001967  0.016538  0.005525  0.002231  127894         98.0
# 39               0.002242  0.018429  0.006175  0.002476  127692         98.0
# 40               0.002533  0.020745  0.006954  0.002788  127895         98.0
# 41               0.002906  0.023510  0.007971  0.003163  127842         98.0
# 42               0.003385  0.028893  0.009493  0.003749  127891         98.0
# 43               0.004321  0.067848  0.013702  0.006342  128490         99.0
#
#                  count %
# factor_quantile
# 1                   2.33
# 2                   2.32
# 3                   2.32
# 4                   2.32
# 5                   2.32
# 6                   2.32
# 7                   2.32
# 8                   2.32
# 9                   2.32
# 10                  2.32
# 11                  2.32
# 12                  2.32
# 13                  2.32
# 14                  2.32
# 15                  2.32
# 16                  2.32
# 17                  2.32
# 18                  2.32
# 19                  2.32
# 20                  2.32
# 21                  2.32
# 22                  2.32
# 23                  2.32
# 24                  2.32
# 25                  2.32
# 26                  2.32
# 27                  2.32
# 28                  2.32
# 29                  2.32
# 30                  2.32
# 31                  2.32
# 32                  2.32
# 33                  2.32
# 34                  2.32
# 35                  2.32
# 36                  2.32
# 37                  2.32
# 38                  2.32
# 39                  2.32
# 40                  2.32
# 41                  2.32
# 42                  2.32
# 43                  2.33
# Turnover Analysis
#                               1D
# Quantile 1 Mean Turnover   0.045
# Quantile 2 Mean Turnover   0.048
# Quantile 3 Mean Turnover   0.049
# Quantile 4 Mean Turnover   0.050
# Quantile 5 Mean Turnover   0.050
# Quantile 6 Mean Turnover   0.050
# Quantile 7 Mean Turnover   0.050
# Quantile 8 Mean Turnover   0.050
# Quantile 9 Mean Turnover   0.051
# Quantile 10 Mean Turnover  0.051
# Quantile 11 Mean Turnover  0.051
# Quantile 12 Mean Turnover  0.051
# Quantile 13 Mean Turnover  0.051
# Quantile 14 Mean Turnover  0.051
# Quantile 15 Mean Turnover  0.051
# Quantile 16 Mean Turnover  0.051
# Quantile 17 Mean Turnover  0.052
# Quantile 18 Mean Turnover  0.052
# Quantile 19 Mean Turnover  0.052
# Quantile 20 Mean Turnover  0.052
# Quantile 21 Mean Turnover  0.052
# Quantile 22 Mean Turnover  0.052
# Quantile 23 Mean Turnover  0.052
# Quantile 24 Mean Turnover  0.052
# Quantile 25 Mean Turnover  0.052
# Quantile 26 Mean Turnover  0.052
# Quantile 27 Mean Turnover  0.052
# Quantile 28 Mean Turnover  0.052
# Quantile 29 Mean Turnover  0.052
# Quantile 30 Mean Turnover  0.052
# Quantile 31 Mean Turnover  0.052
# Quantile 32 Mean Turnover  0.052
# Quantile 33 Mean Turnover  0.052
# Quantile 34 Mean Turnover  0.052
# Quantile 35 Mean Turnover  0.052
# Quantile 36 Mean Turnover  0.052
# Quantile 37 Mean Turnover  0.052
# Quantile 38 Mean Turnover  0.052
# Quantile 39 Mean Turnover  0.051
# Quantile 40 Mean Turnover  0.051
# Quantile 41 Mean Turnover  0.050
# Quantile 42 Mean Turnover  0.049
# Quantile 43 Mean Turnover  0.046
#                                      1D
# Mean Factor Rank Autocorrelation  0.953
# benchmark AnalysisMode Returns Analysis
#                   1D
# Top Ret         1.95
# Bottom Ret     -0.14
# Top RetAE       0.49
# Bottom RetAE   -1.56
# Top RetAE MDD -24.12
# Top RetAE SPR   0.04
# benchmark AnalysisMode Returns Analysis By Year
#       Top Ret  Top RetAE  Bottom Ret  Bottom RetAE  Spread Ret  Spread RetAE  \
# date
# 2019    -0.63      -1.80      -12.25        -13.31       11.62          9.39
# 2020    -8.01      -9.56      -19.13        -20.56       11.13          8.14
# 2021     5.95       4.48        7.41          5.92       -1.45         -4.41
# 2022    17.89      16.40       -1.06         -2.52       18.96         16.01
# 2023    11.24       9.80        8.82          7.41        2.43         -0.42
# 2024   -16.50     -17.96        7.39          5.96      -23.89        -26.79
#
#       RetAE Top SPR  RetAE Top MDD
# date
# 2019          -0.28          -3.50
# 2020          -0.76         -12.74
# 2021           0.39          -7.84
# 2022           1.17         -11.16
# 2023           0.90          -7.86
# 2024          -1.10         -24.12
# Information Analysis
#                    1D
# IC Mean        -0.008
# IR             -0.070
# Good IC Ratio   0.843
# IC Mean SD_20D -0.005
# IR SD_20D      -0.008
# IC Mean SD_60D -0.029
# IR SD_60D      -0.054
#                                       1D
# Top RetAE                       0.487813
# Top RetAE MDD                 -24.124061
# Top RetAE SPR                   0.038020
# IC_20                          -0.004657
# IR_20                          -0.008448
# IC_60                          -0.029054
# IR_60                          -0.054296
# Bottom RetAE                   -1.558832
# Mean turnover Top Quantile      0.044887
# Mean turnover Bottom Quantile   0.046449
# ********************************************************************************************************************************************************************************************************
#
# ********************************************************************************************************************************************************************************************************
# fill_peer_relative_ret------输出贴近实际交易的净值模式指标
#                             value
# Annualized Return(%)    -0.348959
# Annualized ReturnAE(%)  -2.191863
# max_drawdown(%)        -26.406702
# SharpeRatio             -0.173433
# WinP20                   0.523174
# WinP60                   0.515004
# Mean turnover            0.058338
# Mean position            0.977900
#       Return(%)  ReturnAE(%)    SR  mdd(%)
# date
# 2019      -1.33        -2.97 -0.49   -3.43
# 2020     -14.03       -15.95 -1.31  -17.56
# 2021       3.42         1.57  0.14   -9.22
# 2022      18.73        16.86  1.24  -11.23
# 2023       9.49         7.71  0.71   -8.10
# 2024     -18.99       -20.85 -1.29  -26.41
# fill_peer_relative_ret计算完成，耗时0:01:18.837749
# 2023年以前
# **********下行相关性
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********收益回归R2
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********多头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********空头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********
# 全样本除2024年1、2月
# **********下行相关性
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********收益回归R2
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********多头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********空头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
