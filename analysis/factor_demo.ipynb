# %% [markdown]
# # factor_demo

# %% [markdown]
# ## 导入模块

# %%
import sys
sys.path.append('../../public-Git/')

from demo_Alpha.factor_function import *
from utils.stg_functions_local import *
from utils.performance import corr_local_V2

# %matplotlib inline

# %% [markdown]
# ## 定义股票池和基准指数

# %%
stock_universe = '999998'
index_code = '000905'

# %% [markdown]
# ## 定义因子类

# %%
class ret_jump(Factor):
    name = 'fill_neutral_ret_jump'
    islimitbuy = True
    islimitsell = True
    dependencies = ['close']

    def calc(self, data):
        close = data['close']
        factor = feather.read_dataframe('../data/ret_jump/fill_neutral_ret_jump.feather')
        factor = factor.pivot(index='date', columns='issue', values='neutral_factor')
        factor = factor.reindex(index=close.index, columns=close.columns)
        return factor

# %%
class N_connect(Factor):
    name = 'fill_neutral_N_connect_1_both'
    islimitbuy = True
    islimitsell = True
    dependencies = ['close']

    def calc(self, data):
        close = data['close']
        factor = feather.read_dataframe('../data/N_connect_1_both/fill_neutral_N_connect_num.feather')
        factor = factor.pivot(index='date', columns='issue', values='neutral_factor')
        factor = factor.reindex(index=close.index, columns=close.columns)
        return factor

# %% [markdown]
# ## 回测

# %%
start_datetime = datetime.datetime(2019, 1, 1)
end_datetime = datetime.datetime(2024, 5, 31)

factor = ret_jump()

time_tik = datetime.datetime.now()
print(f"开始计算{factor.name}")
factorResults = analysis(
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    factor_objs=[factor,],
    stock_universe=stock_universe,
    benchmark=index_code,
    plot=True
)
print(f"{factor.name}计算完成，耗时{datetime.datetime.now()-time_tik}")

# %
date_index = pd.to_datetime(
    sd.get_trade_date(
        start_datetime.strftime('%Y-%m-%d'),
        end_datetime.strftime('%Y-%m-%d')
    )['trade_date']
)
dailyExcessReturns = (
    factorResults['ret_Data']['ret_wide_ae']
        .iloc[:, -1]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyIC = (
    factorResults['IC_data_raw']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyICLong = (
    factorResults['ic_data_long']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyICShort = (
    factorResults['ic_data_short']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)

print('2023年以前')
RetCorr_Table, RetR2_Table, ICCorr_Table, ICLCorr_Table, ICSCorr_Table = corr_local_V2(
    dailyExcessReturns,
    dailyIC,
    dailyICLong,
    dailyICShort,
    lastday=datetime.datetime(2023, 12, 31),
    warnings=0.6
)
print('*'*10)
print('全样本除2024年1、2月')
RetCorr_Table, RetR2_Table, ICCorr_Table, ICLCorr_Table, ICSCorr_Table = corr_local_V2(
    dailyExcessReturns,
    dailyIC,
    dailyICLong,
    dailyICShort,
    lastday=datetime.datetime(2025, 12, 31),
    warnings=0.6
)
# Out:
# 开始计算fill_neutral_ret_jump
# 因子数据计算完成，耗时0:00:01.309360
# ********************************************************************************************************************************************************************************************************
#
# ********************************************************************************************************************************************************************************************************
# fill_neutral_ret_jump------输出对标超额收益模式指标
# Dropped 0.0% entries from factor data: 0.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 5.0%, not exceeded: OK!
# FactorValues Quantiles Statistics
#                       min       max      mean       std   count  daily_count  \
# factor_quantile
# 1               -0.860557 -0.087306 -0.222072  0.120071  131252        101.0
# 2               -0.329575 -0.072642 -0.127537  0.041274  130602        101.0
# 3               -0.173851 -0.061974 -0.097568  0.019094  130559        101.0
# 4               -0.148065 -0.054840 -0.083416  0.015240  130651        101.0
# 5               -0.129181 -0.048994 -0.073680  0.013355  130600        101.0
# 6               -0.113719 -0.044934 -0.065784  0.011875  130534        101.0
# 7               -0.102461 -0.040521 -0.059349  0.010666  130589        101.0
# 8               -0.091856 -0.036824 -0.053828  0.009539  130698        101.0
# 9               -0.081485 -0.033001 -0.048797  0.008662  130466        101.0
# 10              -0.072622 -0.029311 -0.044236  0.007883  130745        101.0
# 11              -0.063798 -0.025278 -0.039956  0.007158  130429        101.0
# 12              -0.055919 -0.020938 -0.036012  0.006574  130629        101.0
# 13              -0.050779 -0.017818 -0.032218  0.006013  130570        101.0
# 14              -0.045328 -0.014405 -0.028620  0.005523  130591        101.0
# 15              -0.040248 -0.011446 -0.025145  0.005102  130621        101.0
# 16              -0.036081 -0.008009 -0.021704  0.004771  130648        101.0
# 17              -0.031335 -0.005346 -0.018301  0.004541  130467        101.0
# 18              -0.026880 -0.002460 -0.014850  0.004358  130618        101.0
# 19              -0.023560  0.000944 -0.011401  0.004263  130568        101.0
# 20              -0.020061  0.004361 -0.007900  0.004313  130893        101.0
# 21              -0.016828  0.008319 -0.004401  0.004421  130288        100.0
# 22              -0.013100  0.013044 -0.000852  0.004551  130598        101.0
# 23              -0.009307  0.019228  0.002770  0.004871  130588        101.0
# 24              -0.005214  0.024843  0.006610  0.005264  130692        101.0
# 25              -0.000875  0.031001  0.010569  0.005664  130552        101.0
# 26               0.002086  0.037789  0.014696  0.006137  130522        101.0
# 27               0.005015  0.043560  0.019044  0.006636  130561        101.0
# 28               0.008792  0.050632  0.023727  0.007211  130663        101.0
# 29               0.011767  0.058058  0.028810  0.007980  130536        101.0
# 30               0.015916  0.065294  0.034264  0.008794  130729        101.0
# 31               0.019965  0.073294  0.040199  0.009675  130445        101.0
# 32               0.024236  0.080707  0.046794  0.010591  130691        101.0
# 33               0.028206  0.089110  0.054172  0.011532  130473        101.0
# 34               0.033601  0.099182  0.062597  0.012556  130619        101.0
# 35               0.040060  0.111195  0.072228  0.013847  130633        101.0
# 36               0.047958  0.125804  0.083895  0.015294  130564        101.0
# 37               0.057062  0.144712  0.098558  0.017010  130558        101.0
# 38               0.070125  0.177129  0.118911  0.019829  130589        101.0
# 39               0.090500  0.233133  0.151182  0.024501  130572        101.0
# 40               0.120746  0.794539  0.238714  0.070620  131215        101.0
#
#                  count %
# factor_quantile
# 1                   2.51
# 2                   2.49
# 3                   2.49
# 4                   2.50
# 5                   2.49
# 6                   2.49
# 7                   2.49
# 8                   2.50
# 9                   2.49
# 10                  2.50
# 11                  2.49
# 12                  2.50
# 13                  2.49
# 14                  2.49
# 15                  2.50
# 16                  2.50
# 17                  2.49
# 18                  2.49
# 19                  2.49
# 20                  2.50
# 21                  2.49
# 22                  2.49
# 23                  2.49
# 24                  2.50
# 25                  2.49
# 26                  2.49
# 27                  2.49
# 28                  2.50
# 29                  2.49
# 30                  2.50
# 31                  2.49
# 32                  2.50
# 33                  2.49
# 34                  2.49
# 35                  2.50
# 36                  2.49
# 37                  2.49
# 38                  2.49
# 39                  2.49
# 40                  2.51
# Turnover Analysis
#                               1D
# Quantile 1 Mean Turnover   0.073
# Quantile 2 Mean Turnover   0.082
# Quantile 3 Mean Turnover   0.084
# Quantile 4 Mean Turnover   0.087
# Quantile 5 Mean Turnover   0.090
# Quantile 6 Mean Turnover   0.091
# Quantile 7 Mean Turnover   0.091
# Quantile 8 Mean Turnover   0.092
# Quantile 9 Mean Turnover   0.093
# Quantile 10 Mean Turnover  0.094
# Quantile 11 Mean Turnover  0.095
# Quantile 12 Mean Turnover  0.097
# Quantile 13 Mean Turnover  0.097
# Quantile 14 Mean Turnover  0.098
# Quantile 15 Mean Turnover  0.098
# Quantile 16 Mean Turnover  0.099
# Quantile 17 Mean Turnover  0.100
# Quantile 18 Mean Turnover  0.101
# Quantile 19 Mean Turnover  0.103
# Quantile 20 Mean Turnover  0.103
# Quantile 21 Mean Turnover  0.105
# Quantile 22 Mean Turnover  0.105
# Quantile 23 Mean Turnover  0.107
# Quantile 24 Mean Turnover  0.108
# Quantile 25 Mean Turnover  0.109
# Quantile 26 Mean Turnover  0.109
# Quantile 27 Mean Turnover  0.110
# Quantile 28 Mean Turnover  0.112
# Quantile 29 Mean Turnover  0.111
# Quantile 30 Mean Turnover  0.111
# Quantile 31 Mean Turnover  0.110
# Quantile 32 Mean Turnover  0.111
# Quantile 33 Mean Turnover  0.109
# Quantile 34 Mean Turnover  0.108
# Quantile 35 Mean Turnover  0.107
# Quantile 36 Mean Turnover  0.105
# Quantile 37 Mean Turnover  0.103
# Quantile 38 Mean Turnover  0.101
# Quantile 39 Mean Turnover  0.097
# Quantile 40 Mean Turnover  0.090
#                                      1D
# Mean Factor Rank Autocorrelation  0.956
# benchmark AnalysisMode Returns Analysis
#                   1D
# Top Ret       -25.90
# Bottom Ret      1.08
# Top RetAE     -28.73
# Bottom RetAE   -1.22
# Top RetAE MDD -83.46
# Top RetAE SPR  -1.63
# benchmark AnalysisMode Returns Analysis By Year
#       Top Ret  Top RetAE  Bottom Ret  Bottom RetAE  Spread Ret  Spread RetAE  \
# date
# 2019   -12.96     -16.10        5.30          2.74      -18.26        -23.96
# 2020   -28.23     -31.34        0.60         -1.87      -28.82        -34.40
# 2021   -27.08     -29.92       -4.54         -6.76      -22.54        -27.61
# 2022   -36.14     -38.99        6.09          3.92      -42.23        -47.24
# 2023    -9.34     -11.59        9.16          7.31      -18.49        -22.60
# 2024   -62.24     -65.08      -25.75        -28.60      -36.49        -42.17
#
#       RetAE Top SPR  RetAE Top MDD
# date
# 2019          -1.56         -19.81
# 2020          -1.80         -36.32
# 2021          -1.74         -30.73
# 2022          -2.32         -35.37
# 2023          -0.76         -18.47
# 2024          -1.97         -33.95
# Information Analysis
#                    1D
# IC Mean        -0.019
# IR             -0.354
# Good IC Ratio   0.715
# IC Mean SD_20D -0.122
# IR SD_20D      -0.360
# IC Mean SD_60D -0.221
# IR SD_60D      -0.704
#                                       1D
# Top RetAE                     -28.733440
# Top RetAE MDD                 -83.461314
# Top RetAE SPR                  -1.634558
# IC_20                          -0.121542
# IR_20                          -0.360359
# IC_60                          -0.220646
# IR_60                          -0.703835
# Bottom RetAE                   -1.217781
# Mean turnover Top Quantile      0.072665
# Mean turnover Bottom Quantile   0.089776
# ********************************************************************************************************************************************************************************************************
#
# ********************************************************************************************************************************************************************************************************
# fill_neutral_ret_jump------输出贴近实际交易的净值模式指标
#                             value
# Annualized Return(%)   -32.951076
# Annualized ReturnAE(%) -36.001140
# max_drawdown(%)        -88.790243
# SharpeRatio             -2.053202
# WinP20                   0.267506
# WinP60                   0.121852
# Mean turnover            0.096552
# Mean position            1.000000
#       Return(%)  ReturnAE(%)    SR  mdd(%)
# date
# 2019     -20.84       -24.08 -2.49  -24.42
# 2020     -39.87       -43.13 -2.72  -39.61
# 2021     -35.02       -38.11 -2.25  -34.94
# 2022     -42.08       -45.16 -2.63  -40.49
# 2023      -9.77       -12.39 -0.78  -19.46
# 2024     -72.90       -75.94 -2.23  -37.29
# fill_neutral_ret_jump计算完成，耗时0:01:07.313303
# 2023年以前
# **********下行相关性
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********收益回归R2
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********多头IC相关系数
#                      factor
# Shi0037            0.638897
# Shi0037_Small      0.603659
# Zhouwei0005        0.636159
# Zhouwei0005_Small  0.615352
# Zhouwei0008        0.603575
# **********空头IC相关系数
#                      factor
# Zhouwei0008        0.654812
# Zhouwei0008_Mid    0.632023
# Zhouwei0008_Small  0.636231
# **********
# 全样本除2024年1、2月
# **********下行相关性
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********收益回归R2
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********多头IC相关系数
#                      factor
# Shi0037             0.63992
# Shi0037_Small      0.609065
# Zhouwei0005        0.631753
# Zhouwei0005_Small  0.616795
# Zhouwei0008        0.600225
# **********空头IC相关系数
#                      factor
# Zhouwei0008         0.64488
# Zhouwei0008_Mid    0.605861
# Zhouwei0008_Small  0.629519

# %%
start_datetime = datetime.datetime(2019, 8, 1)
end_datetime = datetime.datetime(2024, 12, 31)

factor = N_connect()

time_tik = datetime.datetime.now()
print(f"开始计算{factor.name}")
factorResults = analysis(
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    factor_objs=[factor,],
    stock_universe=stock_universe,
    benchmark=index_code,
    plot=True
)
print(f"{factor.name}计算完成，耗时{datetime.datetime.now()-time_tik}")

# %
date_index = pd.to_datetime(
    sd.get_trade_date(
        start_datetime.strftime('%Y-%m-%d'),
        end_datetime.strftime('%Y-%m-%d')
    )['trade_date']
)
dailyExcessReturns = (
    factorResults['ret_Data']['ret_wide_ae']
        .iloc[:, -1]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyIC = (
    factorResults['IC_data_raw']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyICLong = (
    factorResults['ic_data_long']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyICShort = (
    factorResults['ic_data_short']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)

print('2023年以前')
RetCorr_Table, RetR2_Table, ICCorr_Table, ICLCorr_Table, ICSCorr_Table = corr_local_V2(
    dailyExcessReturns,
    dailyIC,
    dailyICLong,
    dailyICShort,
    lastday=datetime.datetime(2023, 12, 31),
    warnings=0.6
)
print('*'*10)
print('全样本除2024年1、2月')
RetCorr_Table, RetR2_Table, ICCorr_Table, ICLCorr_Table, ICSCorr_Table = corr_local_V2(
    dailyExcessReturns,
    dailyIC,
    dailyICLong,
    dailyICShort,
    lastday=datetime.datetime(2025, 12, 31),
    warnings=0.6
)
# Out:
# 开始计算fill_neutral_N_connect_1_both
# 因子数据计算完成，耗时0:00:01.869798
# ********************************************************************************************************************************************************************************************************
#
# ********************************************************************************************************************************************************************************************************
# fill_neutral_N_connect_1_both------输出对标超额收益模式指标
# Dropped 0.0% entries from factor data: 0.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 5.0%, not exceeded: OK!
# FactorValues Quantiles Statistics
#                          min          max         mean         std   count  \
# factor_quantile
# 1               -2618.326372  -976.140921 -1516.585101  239.733818  118572
# 2               -1665.069160  -876.454223 -1302.505868  173.010130  117964
# 3               -1476.564529  -813.810127 -1175.555996  148.423838  117943
# 4               -1344.010115  -749.228115 -1068.554374  131.898019  117997
# 5               -1175.887732  -672.435983  -972.482769  118.085505  117937
# 6               -1080.651024  -601.881941  -882.895484  107.587050  117968
# 7                -969.929383  -574.446001  -796.935689   89.965834  117960
# 8                -869.990471  -522.934485  -714.643495   71.657041  117994
# 9                -768.066893  -492.945144  -639.234641   58.104325  117951
# 10               -684.981869  -451.293562  -567.476628   49.925598  117948
# 11               -612.316047  -389.649523  -496.442685   44.968043  117976
# 12               -532.395703  -314.070091  -424.992530   42.997635  117969
# 13               -461.535607  -228.488174  -352.547085   43.318261  117970
# 14               -386.866778  -173.603255  -280.041752   42.966070  117962
# 15               -323.010528  -100.861288  -209.239812   41.126285  117964
# 16               -265.845549   -25.322529  -141.087456   40.621538  117962
# 17               -233.879904    31.139736   -75.987176   39.955082  117970
# 18               -193.413818    89.254879   -13.655604   40.294585  117981
# 19               -126.768451   142.529263    46.445669   40.393216  117952
# 20                -97.812329   192.977260   103.082966   40.475071  117953
# 21                -71.659685   244.702601   156.226482   40.801375  117977
# 22                -16.265661   292.727944   206.534271   40.902547  117953
# 23                 59.827003   334.486213   253.705401   41.335601  117952
# 24                109.622808   380.028351   299.000609   40.990561  117981
# 25                159.588486   422.295029   343.733018   40.799338  117970
# 26                187.199043   462.834328   386.402710   40.265674  117962
# 27                225.009354   504.589198   428.529025   39.559962  117964
# 28                298.884606   539.755972   470.050773   39.173441  117962
# 29                335.084238   580.161105   511.219523   39.111174  117970
# 30                388.988717   621.793158   552.000184   39.662035  117969
# 31                422.210596   669.346830   594.233348   40.481741  117976
# 32                473.988189   712.877811   636.398342   41.067367  117948
# 33                504.754630   772.476257   680.111723   42.643210  117951
# 34                537.151237   827.516798   727.014898   44.821580  117994
# 35                575.812290   889.347192   776.429334   48.821972  117960
# 36                627.688586   949.994351   831.100899   54.016449  117968
# 37                673.499890  1027.688471   890.339711   59.717049  117937
# 38                721.234823  1121.180128   959.666819   68.027223  117997
# 39                780.985496  1261.866057  1048.964277   81.186224  117943
# 40                840.140668  1464.530902  1175.673172  102.540009  117964
# 41                982.060525  2803.978428  1446.210694  217.699844  118538
#
#                  daily_count  count %
# factor_quantile
# 1                      101.0     2.45
# 2                      100.0     2.43
# 3                      100.0     2.43
# 4                      100.0     2.43
# 5                      100.0     2.43
# 6                      100.0     2.43
# 7                      100.0     2.43
# 8                      100.0     2.43
# 9                      100.0     2.43
# 10                     100.0     2.43
# 11                     100.0     2.43
# 12                     100.0     2.43
# 13                     100.0     2.43
# 14                     100.0     2.43
# 15                     100.0     2.43
# 16                     100.0     2.43
# 17                     100.0     2.43
# 18                     100.0     2.43
# 19                     100.0     2.43
# 20                     100.0     2.43
# 21                     100.0     2.43
# 22                     100.0     2.43
# 23                     100.0     2.43
# 24                     100.0     2.43
# 25                     100.0     2.43
# 26                     100.0     2.43
# 27                     100.0     2.43
# 28                     100.0     2.43
# 29                     100.0     2.43
# 30                     100.0     2.43
# 31                     100.0     2.43
# 32                     100.0     2.43
# 33                     100.0     2.43
# 34                     100.0     2.43
# 35                     100.0     2.43
# 36                     100.0     2.43
# 37                     100.0     2.43
# 38                     100.0     2.43
# 39                     100.0     2.43
# 40                     100.0     2.43
# 41                     101.0     2.45
# Turnover Analysis
#                               1D
# Quantile 1 Mean Turnover   0.039
# Quantile 2 Mean Turnover   0.061
# Quantile 3 Mean Turnover   0.069
# Quantile 4 Mean Turnover   0.074
# Quantile 5 Mean Turnover   0.077
# Quantile 6 Mean Turnover   0.081
# Quantile 7 Mean Turnover   0.084
# Quantile 8 Mean Turnover   0.087
# Quantile 9 Mean Turnover   0.089
# Quantile 10 Mean Turnover  0.092
# Quantile 11 Mean Turnover  0.093
# Quantile 12 Mean Turnover  0.097
# Quantile 13 Mean Turnover  0.099
# Quantile 14 Mean Turnover  0.100
# Quantile 15 Mean Turnover  0.100
# Quantile 16 Mean Turnover  0.103
# Quantile 17 Mean Turnover  0.104
# Quantile 18 Mean Turnover  0.104
# Quantile 19 Mean Turnover  0.104
# Quantile 20 Mean Turnover  0.105
# Quantile 21 Mean Turnover  0.103
# Quantile 22 Mean Turnover  0.103
# Quantile 23 Mean Turnover  0.104
# Quantile 24 Mean Turnover  0.102
# Quantile 25 Mean Turnover  0.102
# Quantile 26 Mean Turnover  0.101
# Quantile 27 Mean Turnover  0.100
# Quantile 28 Mean Turnover  0.099
# Quantile 29 Mean Turnover  0.098
# Quantile 30 Mean Turnover  0.096
# Quantile 31 Mean Turnover  0.096
# Quantile 32 Mean Turnover  0.094
# Quantile 33 Mean Turnover  0.093
# Quantile 34 Mean Turnover  0.092
# Quantile 35 Mean Turnover  0.090
# Quantile 36 Mean Turnover  0.088
# Quantile 37 Mean Turnover  0.086
# Quantile 38 Mean Turnover  0.082
# Quantile 39 Mean Turnover  0.077
# Quantile 40 Mean Turnover  0.068
# Quantile 41 Mean Turnover  0.043
#                                      1D
# Mean Factor Rank Autocorrelation  0.995
# benchmark AnalysisMode Returns Analysis
#                   1D
# Top Ret        -4.08
# Bottom Ret      5.46
# Top RetAE      -5.44
# Bottom RetAE    4.23
# Top RetAE MDD -35.71
# Top RetAE SPR  -0.44
# benchmark AnalysisMode Returns Analysis By Year
#       Top Ret  Top RetAE  Bottom Ret  Bottom RetAE  Spread Ret  Spread RetAE  \
# date
# 2019   -13.29     -14.44       -6.55         -7.66       -6.74         -9.00
# 2020   -14.26     -15.73        0.76         -0.94      -15.02        -18.19
# 2021    -3.10      -4.53       12.80         11.56      -15.90        -18.56
# 2022    11.73      10.24       13.75         12.52       -2.02         -4.74
# 2023     3.31       2.25       23.43         22.76      -20.11        -21.84
# 2024   -26.49     -27.97      -45.95        -47.37       19.45         16.55
#
#       RetAE Top SPR  RetAE Top MDD
# date
# 2019          -2.35          -6.24
# 2020          -1.82         -15.00
# 2021          -0.35         -15.89
# 2022           1.02          -6.58
# 2023           0.28          -9.88
# 2024          -1.09         -24.81
# Information Analysis
#                    1D
# IC Mean        -0.016
# IR             -0.185
# Good IC Ratio   0.827
# IC Mean SD_20D -0.058
# IR SD_20D      -0.127
# IC Mean SD_60D -0.142
# IR SD_60D      -0.333
#                                       1D
# Top RetAE                      -5.437474
# Top RetAE MDD                 -35.708893
# Top RetAE SPR                  -0.439667
# IC_20                          -0.057711
# IR_20                          -0.126869
# IC_60                          -0.141698
# IR_60                          -0.333205
# Bottom RetAE                    4.233520
# Mean turnover Top Quantile      0.038740
# Mean turnover Bottom Quantile   0.043063
# ********************************************************************************************************************************************************************************************************
#
# ********************************************************************************************************************************************************************************************************
# fill_neutral_N_connect_1_both------输出贴近实际交易的净值模式指标
#                             value
# Annualized Return(%)    -7.160684
# Annualized ReturnAE(%)  -8.731820
# max_drawdown(%)        -44.620406
# SharpeRatio             -0.691958
# WinP20                   0.437772
# WinP60                   0.403968
# Mean turnover            0.049735
# Mean position            1.000000
#       Return(%)  ReturnAE(%)    SR  mdd(%)
# date
# 2019     -12.39       -13.86 -2.35   -5.97
# 2020     -19.82       -21.33 -2.42  -19.54
# 2021      -8.26        -9.95 -0.77  -17.36
# 2022      11.30         9.53  0.92   -6.80
# 2023       2.69         1.38  0.17  -10.63
# 2024     -33.48       -35.15 -1.32  -27.20
# fill_neutral_N_connect_1_both计算完成，耗时0:01:05.357759
# 2023年以前
# **********下行相关性
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********收益回归R2
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********IC相关系数
#                      factor
# Shi0037            0.762973
# Shi0037_Large      0.632423
# Shi0037_Micro      0.697959
# Shi0037_Mid        0.726255
# Shi0037_Small      0.742496
# Zhouwei0005        0.741882
# Zhouwei0005_Micro  0.729477
# Zhouwei0005_Mid    0.691138
# Zhouwei0005_Small  0.756972
# Zhouwei0010        0.645493
# Zhouwei0010_Small  0.688046
# Zhouwei0013        0.786325
# Zhouwei0013_Large  0.676946
# Zhouwei0013_Micro  0.761068
# Zhouwei0013_Mid    0.742878
# Zhouwei0013_Small  0.786925
# Zhouwei0014_Small  0.612052
# Zhouwei0015        0.670569
# Zhouwei0015_Mid    0.657659
# Zhouwei0015_Small  0.680938
# Zhouwei0017        0.639871
# Zhouwei0017_Mid    0.647994
# Zhouwei0017_Small  0.675324
# Zhouwei0019_Small  0.646441
# Zhouwei0020_Small  0.647874
# Zhouwei0022_Small  0.657225
# Zhouwei0023_Small  0.686794
# Zhouwei0024_Small  0.604963
# **********多头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********空头IC相关系数
#                      factor
# Shi0006            0.642038
# Shi0006_Mid        0.617204
# Shi0006_Small      0.677319
# Zhouwei0015        0.655693
# Zhouwei0015_Large  0.612745
# Zhouwei0015_Mid    0.631502
# Zhouwei0019        0.618623
# Zhouwei0019_Large  0.640566
# Zhouwei0019_Mid    0.633757
# Zhouwei0020        0.668431
# Zhouwei0020_Large  0.665611
# Zhouwei0020_Mid    0.688585
# Zhouwei0022        0.604074
# Zhouwei0022_Mid    0.635334
# Zhouwei0023_Mid    0.620065
# **********
# 全样本除2024年1、2月
# **********下行相关性
#               factor
# Style_Size  0.624493
# Sun0006     0.614588
# **********收益回归R2
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********IC相关系数
#                      factor
# Shi0037            0.775887
# Shi0037_Large      0.644957
# Shi0037_Micro      0.713189
# Shi0037_Mid        0.740406
# Shi0037_Small       0.75953
# Zhouwei0005        0.739004
# Zhouwei0005_Micro  0.726753
# Zhouwei0005_Mid    0.694564
# Zhouwei0005_Small  0.759789
# Zhouwei0010        0.671914
# Zhouwei0010_Small  0.710402
# Zhouwei0013        0.798186
# Zhouwei0013_Large  0.685301
# Zhouwei0013_Micro  0.768509
# Zhouwei0013_Mid    0.758021
# Zhouwei0013_Small  0.799261
# Zhouwei0014_Small   0.61703
# Zhouwei0015        0.679667
# Zhouwei0015_Mid    0.658554
# Zhouwei0015_Small  0.695324
# Zhouwei0016_Small   0.60215
# Zhouwei0017        0.642419
# Zhouwei0017_Mid     0.64673
# Zhouwei0017_Small  0.676923
# Zhouwei0019_Small  0.672854
# Zhouwei0020_Small  0.664457
# Zhouwei0022_Small  0.670003
# Zhouwei0023_Small  0.693638
# **********多头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********空头IC相关系数
#                      factor
# Shi0006            0.640551
# Shi0006_Mid        0.610657
# Shi0006_Small       0.67919
# Zhouwei0015        0.642094
# Zhouwei0015_Large  0.608879
# Zhouwei0015_Mid    0.622316
# Zhouwei0019        0.611573
# Zhouwei0019_Large  0.635438
# Zhouwei0019_Mid    0.621088
# Zhouwei0020        0.664887
# Zhouwei0020_Large   0.65452
# Zhouwei0020_Mid     0.68447
# Zhouwei0022_Mid    0.619638
# Zhouwei0023_Mid    0.606788
