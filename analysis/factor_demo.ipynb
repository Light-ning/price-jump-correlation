# %% [markdown]
# # factor_demo

# %% [markdown]
# ## 导入模块

# %%
import sys
sys.path.append('../../public-Git/')

from demo_Alpha.factor_function import *
from utils.stg_functions_local import *
from utils.performance import corr_local_V2

# %matplotlib inline

# %% [markdown]
# ## 定义股票池和基准指数

# %%
stock_universe = '999998'
index_code = '000905'

# %% [markdown]
# ## 定义因子类

# %%
class ret_jump(Factor):
    name = 'fill_ret_jump'
    islimitbuy = True
    islimitsell = True
    dependencies = ['close']

    def calc(self, data):
        close = data['close']
        factor = feather.read_dataframe('../data/ret_jump/fill_neutral_ret_jump.feather')
        factor = factor.pivot(index='date', columns='issue', values='ret_jump')
        factor = factor.reindex(index=close.index, columns=close.columns)
        return factor

# %%
class N_connect(Factor):
    name = 'fill_N_connect'
    islimitbuy = True
    islimitsell = True
    dependencies = ['close']

    def calc(self, data):
        close = data['close']
        factor = feather.read_dataframe('../data/N_connect_1_any/fill_neutral_N_connect_num.feather')
        factor = factor.pivot(index='date', columns='issue', values='neutral_factor')
        factor = factor.reindex(index=close.index, columns=close.columns)
        return factor

# %% [markdown]
# ## 回测

# %%
# start_datetime = datetime.datetime(2019, 1, 1)
# end_datetime = datetime.datetime(2024, 5, 31)

start_datetime = datetime.datetime(2019, 8, 1)
end_datetime = datetime.datetime(2024, 12, 31)

factor = N_connect()

time_tik = datetime.datetime.now()
print(f"开始计算{factor.name}")
factorResults = analysis(
    start_datetime=start_datetime,
    end_datetime=end_datetime,
    factor_objs=[factor,],
    stock_universe=stock_universe,
    benchmark=index_code,
    plot=True
)
print(f"{factor.name}计算完成，耗时{datetime.datetime.now()-time_tik}")

# %
date_index = pd.to_datetime(
    sd.get_trade_date(
        start_datetime.strftime('%Y-%m-%d'),
        end_datetime.strftime('%Y-%m-%d')
    )['trade_date']
)
dailyExcessReturns = (
    factorResults['ret_Data']['ret_wide_ae']
        .iloc[:, -1]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyIC = (
    factorResults['IC_data_raw']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyICLong = (
    factorResults['ic_data_long']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)
dailyICShort = (
    factorResults['ic_data_short']
        .iloc[:, 0]
        .rename('factor')
        .reindex(date_index)
        .shift(1)
        .dropna()
)

print('2023年以前')
RetCorr_Table, RetR2_Table, ICCorr_Table, ICLCorr_Table, ICSCorr_Table = corr_local_V2(
    dailyExcessReturns,
    dailyIC,
    dailyICLong,
    dailyICShort,
    lastday=datetime.datetime(2023, 12, 31),
    warnings=0.6
)
print('*'*10)
print('全样本除2024年1、2月')
RetCorr_Table, RetR2_Table, ICCorr_Table, ICLCorr_Table, ICSCorr_Table = corr_local_V2(
    dailyExcessReturns,
    dailyIC,
    dailyICLong,
    dailyICShort,
    lastday=datetime.datetime(2025, 12, 31),
    warnings=0.6
)
# Out:
# 开始计算fill_N_connect
# 因子数据计算完成，耗时0:00:01.559333
# ********************************************************************************************************************************************************************************************************
#
# ********************************************************************************************************************************************************************************************************
# fill_N_connect------输出对标超额收益模式指标
# Dropped 0.1% entries from factor data: 0.1% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is
# 31                      99.0     2.38
# 32                      99.0     2.38
# 33                      99.0     2.38
# 34                      99.0     2.38
# 35                      99.0     2.37
# 36                      99.0     2.38
# 37                      99.0     2.37
# 38                      99.0     2.37
# 39                      99.0     2.38
# 40                      99.0     2.37
# 41                      99.0     2.38
# 42                      99.0     2.39
# Turnover Analysis
#                               1D
# Quantile 1 Mean Turnover   0.052
# Quantile 2 Mean Turnover   0.070
# Quantile 3 Mean Turnover   0.078
# Quantile 4 Mean Turnover   0.082
# Quantile 5 Mean Turnover   0.086
# Quantile 6 Mean Turnover   0.088
# Quantile 7 Mean Turnover   0.091
# Quantile 8 Mean Turnover   0.092
# Quantile 9 Mean Turnover   0.094
# Quantile 10 Mean Turnover  0.095
# Quantile 11 Mean Turnover  0.096
# Quantile 12 Mean Turnover  0.098
# Quantile 13 Mean Turnover  0.099
# Quantile 14 Mean Turnover  0.100
# Quantile 15 Mean Turnover  0.101
# Quantile 16 Mean Turnover  0.102
# Quantile 17 Mean Turnover  0.102
# Quantile 18 Mean Turnover  0.103
# Quantile 19 Mean Turnover  0.103
# Quantile 20 Mean Turnover  0.102
# Quantile 21 Mean Turnover  0.102
# Quantile 22 Mean Turnover  0.103
# Quantile 23 Mean Turnover  0.102
# Quantile 24 Mean Turnover  0.102
# Quantile 25 Mean Turnover  0.101
# Quantile 26 Mean Turnover  0.102
# Quantile 27 Mean Turnover  0.101
# Quantile 28 Mean Turnover  0.100
# Quantile 29 Mean Turnover  0.099
# Quantile 30 Mean Turnover  0.099
# Quantile 31 Mean Turnover  0.097
# Quantile 32 Mean Turnover  0.097
# Quantile 33 Mean Turnover  0.095
# Quantile 34 Mean Turnover  0.094
# Quantile 35 Mean Turnover  0.092
# Quantile 36 Mean Turnover  0.090
# Quantile 37 Mean Turnover  0.088
# Quantile 38 Mean Turnover  0.084
# Quantile 39 Mean Turnover  0.081
# Quantile 40 Mean Turnover  0.076
# Quantile 41 Mean Turnover  0.067
# Quantile 42 Mean Turnover  0.044
#                                      1D
# Mean Factor Rank Autocorrelation  0.993
# benchmark AnalysisMode Returns Analysis
#                   1D
# Top Ret        -8.65
# Bottom Ret      4.66
# Top RetAE     -10.03
# Bottom RetAE    3.02
# Top RetAE MDD -50.14
# Top RetAE SPR  -0.83
# benchmark AnalysisMode Returns Analysis By Year
#       Top Ret  Top RetAE  Bottom Ret  Bottom RetAE  Spread Ret  Spread RetAE  \
# date
# 2019   -12.82     -13.85      -12.25        -13.58       -0.58         -2.93
# 2020   -11.68     -13.38       -6.47         -8.29       -5.21         -8.74
# 2021   -11.00     -12.51        9.46          7.87      -20.46        -23.56
# 2022    -3.64      -4.98       12.65         11.05      -16.29        -19.24
# 2023    -1.54      -2.61       17.05         15.90      -18.58        -20.80
# 2024   -13.99     -15.38       -3.75         -5.89      -10.24        -13.78
#
#       RetAE Top SPR  RetAE Top MDD
# date
# 2019          -2.18          -6.60
# 2020          -1.29         -13.71
# 2021          -0.95         -21.23
# 2022          -0.47         -14.47
# 2023          -0.32         -11.34
# 2024          -0.89         -24.22
# Information Analysis
#                    1D
# IC Mean        -0.016
# IR             -0.206
# Good IC Ratio   0.812
# IC Mean SD_20D -0.094
# IR SD_20D      -0.194
# IC Mean SD_60D -0.155
# IR SD_60D      -0.345
#                                       1D
# Top RetAE                     -10.027677
# Top RetAE MDD                 -50.138334
# Top RetAE SPR                  -0.834493
# IC_20                          -0.094057
# IR_20                          -0.193892
# IC_60                          -0.155280
# IR_60                          -0.344856
# Bottom RetAE                    3.018430
# Mean turnover Top Quantile      0.051964
# Mean turnover Bottom Quantile   0.043686
# ********************************************************************************************************************************************************************************************************
#
# ********************************************************************************************************************************************************************************************************
# fill_N_connect------输出贴近实际交易的净值模式指标
#                             value
# Annualized Return(%)   -13.098800
# Annualized ReturnAE(%) -14.707781
# max_drawdown(%)        -59.613215
# SharpeRatio             -1.209913
# WinP20                   0.386489
# WinP60                   0.324412
# Mean turnover            0.050933
# Mean position            1.000000
#       Return(%)  ReturnAE(%)    SR  mdd(%)
# date
# 2019     -18.70       -20.08 -3.20   -8.28
# 2020     -19.47       -21.26 -2.06  -19.64
# 2021     -16.51       -18.23 -1.42  -24.09
# 2022      -3.56        -5.20 -0.48  -15.93
# 2023      -4.87        -6.17 -0.75  -12.43
# 2024     -19.17       -20.83 -1.17  -26.29
# fill_N_connect计算完成，耗时0:01:12.090280
# 2023年以前
# **********下行相关性
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********收益回归R2
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********IC相关系数
#                      factor
# Shi0037            0.758874
# Shi0037_Large       0.60741
# Shi0037_Micro      0.703329
# Shi0037_Mid        0.715773
# Shi0037_Small      0.745088
# Zhouwei0005        0.720961
# Zhouwei0005_Micro  0.728993
# Zhouwei0005_Mid    0.663589
# Zhouwei0005_Small  0.745512
# Zhouwei0010        0.648097
# Zhouwei0010_Small  0.695733
# Zhouwei0013        0.779445
# Zhouwei0013_Large  0.655317
# Zhouwei0013_Micro  0.765629
# Zhouwei0013_Mid    0.720752
# Zhouwei0013_Small  0.777474
# Zhouwei0014_Small  0.603578
# Zhouwei0015        0.609076
# Zhouwei0015_Mid    0.602522
# Zhouwei0015_Small  0.636194
# Zhouwei0017         0.61766
# Zhouwei0017_Mid    0.613687
# Zhouwei0017_Small  0.663557
# Zhouwei0019_Small  0.645033
# Zhouwei0020_Small  0.653498
# Zhouwei0022_Small  0.659782
# Zhouwei0023_Small  0.683142
# **********多头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********空头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********
# 全样本除2024年1、2月
# **********下行相关性
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********收益回归R2
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********IC相关系数
#                      factor
# Shi0037            0.759044
# Shi0037_Large      0.610007
# Shi0037_Micro      0.708957
# Shi0037_Mid         0.71517
# Shi0037_Small      0.745543
# Zhouwei0005        0.719281
# Zhouwei0005_Micro  0.726154
# Zhouwei0005_Mid    0.659351
# Zhouwei0005_Small  0.740111
# Zhouwei0010        0.669071
# Zhouwei0010_Small  0.719843
# Zhouwei0013        0.771855
# Zhouwei0013_Large  0.657799
# Zhouwei0013_Micro  0.751854
# Zhouwei0013_Mid    0.720258
# Zhouwei0013_Small   0.76279
# Zhouwei0015        0.630377
# Zhouwei0015_Mid    0.610118
# Zhouwei0015_Small   0.65825
# Zhouwei0017        0.614553
# Zhouwei0017_Mid    0.608902
# Zhouwei0017_Small  0.660468
# Zhouwei0019_Small  0.686176
# Zhouwei0020_Small  0.677847
# Zhouwei0022_Small  0.674818
# Zhouwei0023_Small  0.677323
# **********多头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
# **********空头IC相关系数
# Empty DataFrame
# Columns: [factor]
# Index: []
